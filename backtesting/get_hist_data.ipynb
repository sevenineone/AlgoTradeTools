# %%
import os
from pathlib import Path

import sys
import csv
import ccxt

root = os.path.abspath('')
sys.path.append(root + '/python')


def retry_fetch_ohlcv(exchange, max_retries, symbol, timeframe, since, limit):
    num_retries = 0
    try:
        num_retries += 1
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit)
        # print('Fetched', len(ohlcv), symbol, 'candles from', exchange.iso8601 (ohlcv[0][0]), 'to', exchange.iso8601 (ohlcv[-1][0]))
        return ohlcv
    except Exception:
        if num_retries > max_retries:
            raise  # Exception('Failed to fetch', timeframe, symbol, 'OHLCV in', max_retries, 'attempts')


def scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit):
    earliest_timestamp = exchange.milliseconds()
    timeframe_duration_in_seconds = exchange.parse_timeframe(timeframe)
    timeframe_duration_in_ms = timeframe_duration_in_seconds * 1000
    timedelta = limit * timeframe_duration_in_ms
    all_ohlcv = []
    while True:
        fetch_since = earliest_timestamp - timedelta
        ohlcv = retry_fetch_ohlcv(exchange, max_retries, symbol, timeframe, fetch_since, limit)
        if ohlcv[0][0] >= earliest_timestamp:
            break
        earliest_timestamp = ohlcv[0][0]
        all_ohlcv = ohlcv + all_ohlcv
        print(len(all_ohlcv), symbol, 'candles in total from', exchange.iso8601(all_ohlcv[0][0]), 'to',
              exchange.iso8601(all_ohlcv[-1][0]))
        # if we have reached the checkpoint
        if fetch_since < since:
            break
    return all_ohlcv


def write_to_csv(filename, exchange, data):
    p = Path("./data/raw/", str(exchange))
    p.mkdir(parents=True, exist_ok=True)
    full_path = p / str(filename)
    with Path(full_path).open('w+', newline='') as output_file:
        csv_writer = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        csv_writer.writerows(data)


def scrape_candles_to_csv(path, exchange_id, max_retries, symbol, timeframe, since, limit):
    exchange = getattr(ccxt, exchange_id)({
        'enableRateLimit': True,
    })
    if isinstance(since, str):
        since = exchange.parse8601(since)
    exchange.load_markets()

    filename = f'{path}{exchange.markets.get(symbol)["base"]}_{exchange.markets.get(symbol)["base"]}_{timeframe}.csv'
    ohlcv = scrape_ohlcv(exchange, max_retries, symbol, timeframe, since, limit)
    write_to_csv(filename, exchange, ohlcv)
    print('Saved', len(ohlcv), 'candles from', exchange.iso8601(ohlcv[0][0]), 'to', exchange.iso8601(ohlcv[-1][0]),
          'to', filename)

# %%
symbol = 'ETH/USDT'
timeframe = '15m'

scrape_candles_to_csv('./', 'binanceusdm', 3, symbol, timeframe, '2019-07-15T00:00:00Z', 1000)
# Out:
# 1000 ETH/USDT candles in total from 2022-07-05T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 2000 ETH/USDT candles in total from 2022-06-25T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 3000 ETH/USDT candles in total from 2022-06-14T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 4000 ETH/USDT candles in total from 2022-06-04T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 5000 ETH/USDT candles in total from 2022-05-24T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 6000 ETH/USDT candles in total from 2022-05-14T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 7000 ETH/USDT candles in total from 2022-05-04T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 8000 ETH/USDT candles in total from 2022-04-23T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 9000 ETH/USDT candles in total from 2022-04-13T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 10000 ETH/USDT candles in total from 2022-04-02T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 11000 ETH/USDT candles in total from 2022-03-23T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 12000 ETH/USDT candles in total from 2022-03-12T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 13000 ETH/USDT candles in total from 2022-03-02T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 14000 ETH/USDT candles in total from 2022-02-20T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 15000 ETH/USDT candles in total from 2022-02-09T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 16000 ETH/USDT candles in total from 2022-01-30T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 17000 ETH/USDT candles in total from 2022-01-19T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 18000 ETH/USDT candles in total from 2022-01-09T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 19000 ETH/USDT candles in total from 2021-12-30T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 20000 ETH/USDT candles in total from 2021-12-19T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 21000 ETH/USDT candles in total from 2021-12-09T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 22000 ETH/USDT candles in total from 2021-11-28T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 23000 ETH/USDT candles in total from 2021-11-18T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 24000 ETH/USDT candles in total from 2021-11-07T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 25000 ETH/USDT candles in total from 2021-10-28T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 26000 ETH/USDT candles in total from 2021-10-18T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 27000 ETH/USDT candles in total from 2021-10-07T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 28000 ETH/USDT candles in total from 2021-09-27T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 29000 ETH/USDT candles in total from 2021-09-16T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 30000 ETH/USDT candles in total from 2021-09-06T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 31000 ETH/USDT candles in total from 2021-08-27T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 32000 ETH/USDT candles in total from 2021-08-16T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 33000 ETH/USDT candles in total from 2021-08-06T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 34000 ETH/USDT candles in total from 2021-07-26T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 35000 ETH/USDT candles in total from 2021-07-16T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 36000 ETH/USDT candles in total from 2021-07-05T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 37000 ETH/USDT candles in total from 2021-06-25T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 38000 ETH/USDT candles in total from 2021-06-15T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 39000 ETH/USDT candles in total from 2021-06-04T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 40000 ETH/USDT candles in total from 2021-05-25T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 41000 ETH/USDT candles in total from 2021-05-14T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 42000 ETH/USDT candles in total from 2021-05-04T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 43000 ETH/USDT candles in total from 2021-04-24T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 44000 ETH/USDT candles in total from 2021-04-13T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 45000 ETH/USDT candles in total from 2021-04-03T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 46000 ETH/USDT candles in total from 2021-03-23T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 47000 ETH/USDT candles in total from 2021-03-13T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 48000 ETH/USDT candles in total from 2021-03-02T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 49000 ETH/USDT candles in total from 2021-02-20T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 50000 ETH/USDT candles in total from 2021-02-10T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 51000 ETH/USDT candles in total from 2021-01-30T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 52000 ETH/USDT candles in total from 2021-01-20T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 53000 ETH/USDT candles in total from 2021-01-09T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 54000 ETH/USDT candles in total from 2020-12-30T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 55000 ETH/USDT candles in total from 2020-12-20T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 56000 ETH/USDT candles in total from 2020-12-09T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 57000 ETH/USDT candles in total from 2020-11-29T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 58000 ETH/USDT candles in total from 2020-11-18T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 59000 ETH/USDT candles in total from 2020-11-08T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 60000 ETH/USDT candles in total from 2020-10-28T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 61000 ETH/USDT candles in total from 2020-10-18T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 62000 ETH/USDT candles in total from 2020-10-08T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 63000 ETH/USDT candles in total from 2020-09-27T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 64000 ETH/USDT candles in total from 2020-09-17T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 65000 ETH/USDT candles in total from 2020-09-06T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 66000 ETH/USDT candles in total from 2020-08-27T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 67000 ETH/USDT candles in total from 2020-08-17T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 68000 ETH/USDT candles in total from 2020-08-06T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 69000 ETH/USDT candles in total from 2020-07-27T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 70000 ETH/USDT candles in total from 2020-07-16T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 71000 ETH/USDT candles in total from 2020-07-06T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 72000 ETH/USDT candles in total from 2020-06-25T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 73000 ETH/USDT candles in total from 2020-06-15T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 74000 ETH/USDT candles in total from 2020-06-05T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 75000 ETH/USDT candles in total from 2020-05-25T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 76000 ETH/USDT candles in total from 2020-05-15T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 77000 ETH/USDT candles in total from 2020-05-04T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 78000 ETH/USDT candles in total from 2020-04-24T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 79000 ETH/USDT candles in total from 2020-04-14T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 80000 ETH/USDT candles in total from 2020-04-03T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 81000 ETH/USDT candles in total from 2020-03-24T04:00:00.000Z to 2022-07-15T21:45:00.000Z
# 82000 ETH/USDT candles in total from 2020-03-13T18:00:00.000Z to 2022-07-15T21:45:00.000Z
# 83000 ETH/USDT candles in total from 2020-03-03T08:00:00.000Z to 2022-07-15T21:45:00.000Z
# 84000 ETH/USDT candles in total from 2020-02-21T22:00:00.000Z to 2022-07-15T21:45:00.000Z
# 85000 ETH/USDT candles in total from 2020-02-11T12:00:00.000Z to 2022-07-15T21:45:00.000Z
# 86000 ETH/USDT candles in total from 2020-02-01T02:00:00.000Z to 2022-07-15T21:45:00.000Z
# 87000 ETH/USDT candles in total from 2020-01-21T16:00:00.000Z to 2022-07-15T21:45:00.000Z
# 88000 ETH/USDT candles in total from 2020-01-11T06:00:00.000Z to 2022-07-15T21:45:00.000Z
# 89000 ETH/USDT candles in total from 2019-12-31T20:00:00.000Z to 2022-07-15T21:45:00.000Z
# 90000 ETH/USDT candles in total from 2019-12-21T10:00:00.000Z to 2022-07-15T21:45:00.000Z
# 91000 ETH/USDT candles in total from 2019-12-11T00:00:00.000Z to 2022-07-15T21:45:00.000Z
# 92000 ETH/USDT candles in total from 2019-11-30T14:00:00.000Z to 2022-07-15T21:45:00.000Z
# 93000 ETH/USDT candles in total from 2019-11-27T07:45:00.000Z to 2022-07-15T21:45:00.000Z
# Saved 93000 candles from 2019-11-27T07:45:00.000Z to 2022-07-15T21:45:00.000Z to ./ETH_USDT_15m.csv
